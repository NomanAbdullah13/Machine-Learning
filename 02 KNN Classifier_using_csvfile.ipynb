# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv("/content/drive/MyDrive/ML101.csv")
dataset.head()
# Out:
#    height  weight        class
# 0      63      82       Normal
# 1      65      50  Underweight
# 2      40      60       Normal
# 3      63      64       Normal
# 4      29      50       Normal

# %% [markdown]
# **Data**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
height = dataset.iloc[:, :-1].values
weight = dataset.iloc[:, :-1].values
classes = dataset.iloc[:, -1].values

# %%
classes
# Out:
# array(['Normal', 'Underweight', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Underweight', 'Underweight', 'Underweight', 'Normal',
#        'Underweight', 'Underweight', 'Normal', 'Normal', 'Underweight',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Underweight', 'Normal',
#        'Underweight', 'Underweight', 'Normal', 'Underweight', 'Normal',
#        'Underweight', 'Normal', 'Normal', 'Normal', 'Underweight',
#        'Underweight', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Underweight', 'Underweight', 'Underweight', 'Underweight',
#        'Normal', 'Underweight', 'Normal', 'Normal', 'Normal',
#        'Underweight', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Underweight', 'Normal', 'Underweight', 'Normal', 'Underweight',
#        'Underweight', 'Underweight', 'Underweight', 'Normal', 'Normal',
#        'Underweight', 'Normal', 'Normal', 'Underweight', 'Normal',
#        'Underweight', 'Normal', 'Normal', 'Underweight', 'Normal',
# ...

# %%
weight
# Out:
# array([[ 63,  82],
#        [ 65,  50],
#        [ 40,  60],
#        [ 63,  64],
#        [ 29,  50],
#        [ 28,  44],
#        [ 32,   8],
#        [ 85,  53],
#        [ 80,  53],
#        [ 54,  68],
#        [ 60,  45],
#        [ 82,  19],
#        [  6, 100],
#        [ 10,  52],
#        [ 59,  14],
#        [ 60,  91],
#        [ 26,  70],
#        [  9,  76],
#        [ 66,  93],
#        [ 45,  27],
#        [ 34,  82],
#        [ 71,  11],
#        [ 36,  12],
#        [ 27,  39],
#        [ 99,  86],
#        [ 14,  20],
#        [ 91,  71],
#        [ 40,  65],
#        [ 29,  56],
#        [ 86,  91],
#        [ 96,  50],
#        [ 76,  36],
#        [ 58,  79],
#        [ 51,  86],
#        [ 60,  68],
#        [ 42,  46],
#        [ 40,  98],
#        [ 90,  79],
#        [ 48,  38],
#        [ 92,  45],
#        [ 65,  43],
#        [  2,  26],
#        [ 40,  19],
#        [ 27,  99],
#        [ 73,  79],
#        [ 25,  35],
#        [ 73,  53],
# ...

# %%
height
# Out:
# array([[ 63,  82],
#        [ 65,  50],
#        [ 40,  60],
#        [ 63,  64],
#        [ 29,  50],
#        [ 28,  44],
#        [ 32,   8],
#        [ 85,  53],
#        [ 80,  53],
#        [ 54,  68],
#        [ 60,  45],
#        [ 82,  19],
#        [  6, 100],
#        [ 10,  52],
#        [ 59,  14],
#        [ 60,  91],
#        [ 26,  70],
#        [  9,  76],
#        [ 66,  93],
#        [ 45,  27],
#        [ 34,  82],
#        [ 71,  11],
#        [ 36,  12],
#        [ 27,  39],
#        [ 99,  86],
#        [ 14,  20],
#        [ 91,  71],
#        [ 40,  65],
#        [ 29,  56],
#        [ 86,  91],
#        [ 96,  50],
#        [ 76,  36],
#        [ 58,  79],
#        [ 51,  86],
#        [ 60,  68],
#        [ 42,  46],
#        [ 40,  98],
#        [ 90,  79],
#        [ 48,  38],
#        [ 92,  45],
#        [ 65,  43],
#        [  2,  26],
#        [ 40,  19],
#        [ 27,  99],
#        [ 73,  79],
#        [ 25,  35],
#        [ 73,  53],
# ...

# %% [markdown]
# **Plot the data using matplotlib**

# %%
# prompt: plot X1 and X2 as points as red for Underweight and green for normal

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(height[classes == 'Underweight'], weight[classes == 'Underweight'], color='red', label='Underweight')
plt.scatter(height[classes == 'Normal'], weight[classes == 'Normal'], color='green', label='Normal')
plt.scatter(170, 57, color='black', label='unknown?')
plt.xlabel('height')
plt.ylabel('weight')
plt.title('Scatter Plot of height and weight')
plt.legend()
plt.show()

# %% [markdown]
# **Implementing the Eucledian Distance Method**
# <br> between two data points (x1, y1) and (x2,y2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Euclidean distance calculation
def euclidean_distance(point1, point2):
  return np.sqrt(np.sum((point1 - point2)**2)).round(2)

# Given point
point = np.array([170, 57])

# Calculate distances
distances = []
for i in range(len(height)):
  distances.append(euclidean_distance(point, np.array([height[i], weight[i]])))

distances
# Out:
# [155.4,
#  148.82,
#  183.9,
#  151.64,
#  199.65,
#  201.66,
#  207.1,
#  120.34,
#  127.4,
#  164.78,
#  156.49,
#  135.56,
#  239.77,
#  226.38,
#  168.34,
#  162.83,
#  204.47,
#  229.27,
#  155.64,
#  181.8,
#  195.56,
#  154.38,
#  199.9,
#  203.83,
#  108.46,
#  226.74,
#  113.46,
#  184.2,
#  199.41,
#  128.16,
#  105.12,
#  136.21,
#  161.42,
#  173.22,
#  156.34,
#  181.69,
#  192.77,
#  117.34,
#  174.61,
#  111.61,
#  149.81,
#  241.6,
#  191.54,
#  210.77,
#  140.66,
#  207.41,
#  137.3,
#  234.83,
#  168.44,
#  157.43,
#  208.63,
#  222.08,
#  113.46,
#  126.49,
#  107.71,
#  233.66,
#  142.9,
#  166.97,
#  237.93,
#  110.94,
#  227.41,
#  223.99,
#  144.14,
#  221.11,
#  210.64,
#  178.89,
#  233.31,
#  157.1,
#  224.89,
#  189.13,
#  153.08,
#  219.66,
#  124.96,
#  145.77,
#  201.72,
#  231.93,
#  220.62,
#  136.68,
#  214.4,
#  134.46,
#  137.3,
#  148.55,
#  173.95,
#  146.49,
#  231.21,
#  204.0,
#  222.4,
#  212.36,
#  203.96,
#  123.49,
#  171.03,
#  203.3,
# ...

# %%
# prompt: order values in distances and take first 3 to cout max class
K = 3
# Create a DataFrame for better handling
df_distances = pd.DataFrame({'distance': distances, 'class': classes})

# Sort by distance and get the first 3
nearest_neighbors = df_distances.sort_values(by='distance').head(K)

# Count the occurrences of each class among the nearest neighbors
class_counts = nearest_neighbors['class'].value_counts()

# Get the class with the maximum count
max_class = class_counts.index[0]

print(f"The majority class among the {K} nearest neighbors is: {max_class}")
# Out:
# The majority class among the 3 nearest neighbors is: Underweight
